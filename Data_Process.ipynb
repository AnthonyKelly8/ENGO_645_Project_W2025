# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/ENGO_645/ENGO_645_Project_W2025/
# Out:
# /content/drive/MyDrive/ENGO_645/ENGO_645_Project_W2025

# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
Nevada = gpd.read_file('Data/Nevada_Border/us_state.shp')
Nevada = Nevada[Nevada['NAME'] == 'Nevada']

# %%
Mines = gpd.read_file('Data/Mines/sedau.shp')
Mines_in_Nevada = gpd.sjoin(Mines, Nevada, how='inner', predicate='intersects')

# %%
Min_Occ = gpd.read_file('Data/Mineral_Occurence/mrds-fUS32.shp')
filtered_Min_Occ = Min_Occ[Min_Occ['score'].isin(['A', 'B', 'C'])]
filtered_Min_Occ = filtered_Min_Occ.drop(columns=['url','dep_id','mrds_id','mas_id','site_name','region','country','state','county','com_type','oper_type','dep_type','prod_size','dev_stat','work_type','model','conc_proc','names','ore_ctrl','reporter','hrock_unit','arock_unit','arock_type','ref'])
filtered_Min_Occ = pd.DataFrame(filtered_Min_Occ)
filtered_Min_Occ
# Out:
#        latitude  longitude                  commod1       commod2  \
# 8      37.90107  -114.4739  Manganese, Silver, Lead          None
# 9      37.69386  -114.5239       Lead, Gold, Silver  Zinc, Copper
# 10     35.95193  -115.4658             Copper, Lead  Silver, Gold
# 11     35.93610  -115.4677       Copper, Lead, Zinc          None
# 12     35.93110  -115.4733                     Zinc  Silver, Lead
# ...         ...        ...                      ...           ...
# 15389  40.54330  -117.5603                   Copper          None
# 15424  39.26660  -119.6177             Gold, Silver        Copper
# 15433  39.41433  -116.0587                     Gold        Silver
# 15434  40.61660  -117.0542     Silver, Copper, Lead          Gold
# 15438  38.28632  -118.9017             Silver, Gold          None
#
#                                commod3  \
# 8      Zinc, Vanadium, Copper, Arsenic
# 9                             Vanadium
# 10                            Vanadium
# ...

# %%
m = folium.Map(location=[38.8026, -116.4194], zoom_start = 6)

folium.GeoJson(Nevada).add_to(m)
folium.GeoJson(Mines_in_Nevada).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
